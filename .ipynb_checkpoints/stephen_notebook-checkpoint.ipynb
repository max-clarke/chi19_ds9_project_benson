# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import pickle

# %%
with open('pickles/may18_turnstiles.pickle', 'rb') as pik:
    data = pickle.load(pik)

# %%
new_df = pd.DataFrame(data)

# %%
df = new_df

# %%
df.columns = [column.strip() for column in df.columns]

# %%
df['DATETIME'] = pd.to_datetime(df.DATE +" " + df.TIME, format='%m/%d/%Y %H:%M:%S')

# %%
df['WEEKDAY_NUM'] = [dt.weekday() for dt in df['DATETIME']]

# %%
weekdays = {0: 'Monday',1: 'Tuesday',2: 'Wednesday',3: 'Thursday',4: 'Friday',5: 'Saturday',6: 'Sunday'}
df['WEEKDAY'] = [weekdays[day] for day in df['WEEKDAY_NUM']]

# %%
with open('pickles/with_weekdays.pickle', 'wb') as writer:
    pickle.dump(df, writer)

# %%
df = df.drop(['WEEKDAY_NUM'],axis=1)

# %%
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/19/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/19/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/19/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/19/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/19/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/19/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/20/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/20/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/20/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/20/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  05/20/2018
# ...

# %%
grouped = df.groupby(['C/A','UNIT','SCP','STATION','DATE','WEEKDAY','TIME'], as_index = False)

# %%
daily_df = grouped.sum()

# %%
daily_df = daily_df.sort_values(['C/A', 'UNIT', 'SCP', 'STATION', 'DATE', 'WEEKDAY', 'TIME'])

# %%
daily_df['ENTRIES'] = daily_df['ENTRIES'].diff()

# %%
daily_df['EXITS'] = daily_df['EXITS'].diff()

# %%
# Out:
#           C/A  UNIT       SCP        STATION        DATE    WEEKDAY      TIME  \
# 0        A002  R051  02-00-00          59 ST  04/28/2018   Saturday  00:00:00
# 1        A002  R051  02-00-00          59 ST  04/28/2018   Saturday  04:00:00
# 2        A002  R051  02-00-00          59 ST  04/28/2018   Saturday  08:00:00
# 3        A002  R051  02-00-00          59 ST  04/28/2018   Saturday  12:00:00
# 4        A002  R051  02-00-00          59 ST  04/28/2018   Saturday  16:00:00
# 5        A002  R051  02-00-00          59 ST  04/28/2018   Saturday  20:00:00
# 6        A002  R051  02-00-00          59 ST  04/29/2018     Sunday  00:00:00
# 7        A002  R051  02-00-00          59 ST  04/29/2018     Sunday  04:00:00
# 8        A002  R051  02-00-00          59 ST  04/29/2018     Sunday  08:00:00
# 9        A002  R051  02-00-00          59 ST  04/29/2018     Sunday  12:00:00
# 10       A002  R051  02-00-00          59 ST  04/29/2018     Sunday  16:00:00
# ...
