# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_may18_week1 = pd.read_csv('data/turnstile_180505.csv')
df_may18_week2 = pd.read_csv('data/turnstile_180512.csv')
df_may18_week3 = pd.read_csv('data/turnstile_180519.csv')
df_may18_week4 = pd.read_csv('data/turnstile_180526.csv')

df_may18 = df_may18_week1.append(df_may18_week2)
df_may18 = df_may18_week1.append(df_may18_week3)
df_may18 = df_may18_week1.append(df_may18_week4)

# %%
df_may18
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/29/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/29/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/29/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/29/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/29/2018
# ...

# %%
df_may18_week2.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6607801
# 1  REGULAR  6607821
# 2  REGULAR  6607830
# 3  REGULAR  6607921
# 4  REGULAR  6608151
#
#    EXITS
# 0                                            2239047
# 1                                            2239051
# 2                                            2239083
# 3                                            2239160
# 4                                            2239219
